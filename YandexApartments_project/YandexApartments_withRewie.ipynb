# %% [markdown]
# ## **Комментарий ревьюера**
#
# Привет 👋
#
# Меня зовут Кузьмич Валентин, и я буду проверять твой проект. Предлагаю сразу договориться общаться на «ты», если для тебя это не уместно, то дай, пожалуйста, знать, будем общаться на «вы».
#
# ### **Краткое резюме по ревью**
#
# <div style="border-radius: 15px; box-shadow: 2px 2px 4px; border: 1px solid; background:Gainsboro; padding: 20px">
#
# Видны твои старания при работе над данным проектом. Большинство основных этапов в работе сделано хорошо:
# - есть много сильных и интересных алгоритмов 🤩
# - детально изучены многие тонкости данных
# - здорово сделана предобработка данных
# - качественно исследованы данные
# - построено много интересных графиков
# - сделано много верных промежуточных выводов, основанных на полученных данных
#
# Твоего внимания требует:
# - небольшое исправление графиков
# - пересмотр выводов
# - исправление ошибки в коде
#
# Я описал замечания в комментариях, которые помечены цветом(красным, желтым), после их доработки я смогу принять работу.
#
# Спасибо тебе за твой труд! Я на все 100% уверен, что у тебя все получится, и с нетерпением буду ждать твою работу на повторное ревью 😉
#
# </div>
#
# ### **PS:**
#
# Хочу поделиться дополнительным материалом, он бесплатный, но объемный(может уйти несколько месяцев):
# - У Тимофея Хирьянова есть [Плей-лист по алгоритмам на python](https://www.youtube.com/playlist?list=PLRDzFCPr95fK7tr47883DFUbm4GeOjjc0), это вроде просто видео-лекции, но в описании есть ссылка на лекции и практику, не стесняйся смотреть, преподаватель очень наглядно объясняет материал. На первых уроках задания могут показаться сложными, так как требует знания геометрии, не стесняйся проходить далее, будет проще)
#
# И вот доп ссылки на статьи по корреляции:
# - [Шкала Чеддока…](https://ekonometrik.ru/%D1%88%D0%BA%D0%B0%D0%BB%D0%B0-%D1%87%D0%B5%D0%B4%D0%B4%D0%BE%D0%BA%D0%B0/), тут есть табличка по тому, как интерпретировать корреляцию
# - [Линейный коэффициент корреляции Пирсона](https://statanaliz.info/statistica/korrelyaciya-i-regressiya/linejnyj-koefficient-korrelyacii-pirsona/)
# - [Корреляция и регрессия](https://stepik.org/lesson/8086/step/1?unit=1365), это небольшой курс на степике, в котором можно пройти только нужные тебе блоки
# - [Корреляция и каузальность](https://pikabu.ru/story/korrelyatsiya_i_kauzalnost_5956601)
#
# ### **Правила оформления:**
#
# По ходу тетрадки ты найдешь комментарии к проекту, они будут в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Постарайся учесть эти комментарии для дальнейших проектов. Я использую заголовки в комментариях, они изменят твое оглавление. Но тебе будет удобно перемещаться от комментария к комментарию. А перед перемещением проекта в портфолио просто уберешь данные комментарии.
#
# Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта быстрее.
#
# Я буду красить комментарии цветом:
#
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h4> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h4>
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
#
# Также жду от тебя комментарии, где вкратце опишешь изменения, которые были внесены.
# </div>
#
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h4> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h4>
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
#
# В случае изменений кода, опиши, пожалуйста, вкратце то, что изменилось. Если изменений не было, то просто опиши свои мысли на эту тему.
# </div>
#
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h4> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h4>
#
# Такой комментарий говорит о том, что было сделано что-то качественное и правильное 😃
#
# Я не буду ждать твоего комментария, но буду ему очень рад 🤗
# </div>
#
# Чтобы мы были на одной волне, рекомендую общаться в том же стиле 😊 Твои ответы на мои комментарии будут подкрашиваться в синий цвет.
#
# Ниже я оформил образец для твоего удобства, тебе остается только добавить после моего комментария ячейку с типом **Markdown**, скопировать туда код(чтобы увидеть код дважды, кликни на ячейку) из образца и написать свои мысли по поводу комментария.

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Напиши здесь свои мысли и идеи по поводу комментария ревьюера.
#
# </div>

# %% [markdown]
# ## **Комментарий ревьюера v2**
#
# ### **Краткое резюме по ревью**
# <div style="border-radius: 15px; box-shadow: 2px 2px 4px; border: 1px solid; background:Gainsboro; padding: 20px">
#
# Молодец, исправлено:
# - небольшое исправление графиков
# - пересмотр выводов
# - исправление ошибки в коде
#
# Спасибо тебе за твой труд! Я готов принять работу. Успехов в дальнейшем обучении!
#
# </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Спасибо, что есть оглавление в плагине toc. Теперь по проекту удобно перемещаться.
#
# Здорово, что во вступлении к твоему проекту есть
#
# - заголовок,
#
# - краткое описание проекта,
#
# - цель проекта
#
# Вступление станет лучше, если ты добавишь в него:
#
# - описание данных,
#
# - план работы
#
# Тогда получатель отчета сможет быстрей его понять.
#
# </div>

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
pd.set_option('display.max_columns', 50) 
data.head() #первые 5 строк датасета
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0         51.0      8          NaN   False
# 1             NaN          11.0         18.6      1          NaN   False
# 2             NaN           5.0         34.3      4          NaN   False
# 3             NaN          14.0          NaN      9          NaN   False
# 4            3.03          14.0         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h5>
#
# 1. Блок загрузки библиотек лучше размещать в отдельной от остального кода ячейке. Такой подход позволит улучшить читаемость кода, снизит время поиска ошибок (если они есть) и исключит повторное выполнение кода.
#
# 2. При выводе df.head() можно увидеть, что часть столбцов заменилась на «...»
#
#     Чтобы это поправить можно поправить настройки pandas:
#
#     ```python
#     pd.set_option('display.max_columns', 50)
#     ```
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента</font></h5>
#
# Спасибо, добавил.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍
#
# </div>

# %%
data.tail() #последние 5 строк датасета
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 23694             3.7           5.0         73.3      3          NaN   False
# 23695             NaN           5.0         38.0      4          NaN   False
# 23696             NaN           3.0         29.7      1          NaN   False
# 23697             3.0          17.0          NaN     12          NaN   False
# 23698             2.5           5.0         12.3      1          NaN   False
#
#        open_plan  kitchen_area  balcony        locality_name  \
# ...

# %% [markdown]
# Проверим общую информацию о данных:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Отлично, построены гистограммы по всем столбцам!
#
# Вывод перед графиком немного мешает. Он выводится так как jupyter notebook выводит на экран информацию об объекте в последней строке, чтобы этого не было, можно в конец добавить None, эти непонятные строки выводиться не будут. Показал в примере ниже.
#
# </div>

# %%
# Код ревьюера

data.hist(figsize=(15, 20))
None

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  12180.000000
# mean      10.673824     34.457852      5.892358     10.569807      1.150082
# ...

# %% [markdown]
# Посмотрим, в каких столбцах есть пропущенные значения:

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Выведем число пропусков в процентах:

# %%
data.isna().mean().sort_values(ascending=False)*100
# Out:
# is_apartment            88.290645
# parks_nearest           65.909954
# ponds_nearest           61.559559
# balcony                 48.605426
# ceiling_height          38.799105
# airports_nearest        23.384953
# cityCenters_nearest     23.287902
# ponds_around3000        23.283683
# parks_around3000        23.283683
# days_exposition         13.422507
# kitchen_area             9.612220
# living_area              8.029875
# floors_total             0.362885
# locality_name            0.206760
# total_images             0.000000
# last_price               0.000000
# studio                   0.000000
# floor                    0.000000
# rooms                    0.000000
# first_day_exposition     0.000000
# total_area               0.000000
# open_plan                0.000000
# dtype: float64

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Хорошо, что изучено соотношение пропущенных данных, это отличная практика.
#
# </div>

# %% [markdown]
# Посмотрим число явных дубликатов:

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Первые выводы:**
#
# Исходя из вывода `info()` можно заметить, что тип данных стобца `is_apartment` - object, что неверно, так как он должен быть булевым. Также столбец `first_day_exposition` необходимо преобразовать в тип `datetime`. Название стобца `cityCenters_nearest` стоит поменять на `city_сenters_nearest` для соблюдения регистра.
#
# Из полученного вывода методом `describe()` было замечено максимальное значение высоты потолков - 100 метров, что намекает на то, что в столбце `ceiling_height` имеются аномальные значения. Скорее всего необходимо убрать один значащий ноль для таких значений. Минимальное значение высоты потолков равно 1, что тоже является аномальным значением.
#
# Наблюдается большое количество пропусков в данных. Всего **14** столбцов с пропущенными значениями. Максимальное количество пропущенных значений в одном столбце достигает **88.3%**.
#
# Явных дубликатов в данных не найдено. Стоит поискать неявные.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Хороший, красиво оформленный, промежуточный вывод, сразу понятно, что будет далее в предобработке.
#
# </div>

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# Обработаем данные из столбца `is_apartment`:

# %%
data['is_apartment'].unique() # смотрим уникальные значения столбца
# Out:
# array([nan, False, True], dtype=object)

# %% [markdown]
# Предположительно, пропуски означают, что пользователь не заполнил информацию об апартаментах, так как помещение не является апартаментами. Заменим все пропуски на `False`:

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)

# %%
data['is_apartment'].value_counts()
# Out:
# False    23649
# True        50
# Name: is_apartment, dtype: int64

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h5>
#
# Приведение к типу данных лучше вынести в отдельный блок, чтобы были видны преобразования сразу по всем колонкам в одном месте.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента</font></h5>
#
# Вынес в отдельный блок в ячейке 74.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍
#
# </div>

# %% [markdown]
# Снова выведем пропуски и общую информацию:

# %%
print(data.isna().mean().sort_values(ascending=False)*100)
print(data.info())
# Out:
# parks_nearest           65.909954
# ponds_nearest           61.559559
# balcony                 48.605426
# ceiling_height          38.799105
# airports_nearest        23.384953
# cityCenters_nearest     23.287902
# ponds_around3000        23.283683
# parks_around3000        23.283683
# days_exposition         13.422507
# kitchen_area             9.612220
# living_area              8.029875
# floors_total             0.362885
# locality_name            0.206760
# total_images             0.000000
# last_price               0.000000
# studio                   0.000000
# is_apartment             0.000000
# floor                    0.000000
# rooms                    0.000000
# first_day_exposition     0.000000
# total_area               0.000000
# open_plan                0.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ...

# %% [markdown]
# Обработаем данные из столбца `balcony`:

# %%
data['balcony'].unique() # смотрим уникальные значения столбца
# Out:
# array([nan,  2.,  0.,  1.,  5.,  4.,  3.])

# %% [markdown]
# Предположительно, пропуски означают, что пользователь не заполнил информацию о наличии балкона, так как помещение не имеет балкона. Заменим все пропуски на 0:

# %%
data['balcony'] = data['balcony'].fillna(0)
data['balcony'].value_counts()
# Out:
# 0.0    15277
# 1.0     4195
# 2.0     3659
# 5.0      304
# 4.0      183
# 3.0       81
# Name: balcony, dtype: int64

# %% [markdown]
# Снова выведем пропуски и общую информацию:

# %%
print(data.isna().mean().sort_values(ascending=False)*100)
print(data.info())
# Out:
# parks_nearest           65.909954
# ponds_nearest           61.559559
# ceiling_height          38.799105
# airports_nearest        23.384953
# cityCenters_nearest     23.287902
# ponds_around3000        23.283683
# parks_around3000        23.283683
# days_exposition         13.422507
# kitchen_area             9.612220
# living_area              8.029875
# floors_total             0.362885
# locality_name            0.206760
# balcony                  0.000000
# total_images             0.000000
# last_price               0.000000
# studio                   0.000000
# is_apartment             0.000000
# floor                    0.000000
# rooms                    0.000000
# first_day_exposition     0.000000
# total_area               0.000000
# open_plan                0.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ...

# %% [markdown]
# Заменим тип данных столбца `first_day_exposition` на `datetime`. Данные в столбце округлены до дней, тем самым зададим формат Год-Месяц-День:

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format = '%Y-%m-%d')
data['first_day_exposition'].head
# Out:
# <bound method NDFrame.head of 0       2019-03-07
# 1       2018-12-04
# 2       2015-08-20
# 3       2015-07-24
# 4       2018-06-19
#            ...
# 23694   2017-03-21
# 23695   2018-01-15
# 23696   2018-02-11
# 23697   2017-03-28
# 23698   2017-07-21
# Name: first_day_exposition, Length: 23699, dtype: datetime64[ns]>

# %% [markdown]
# Переименуем столбец `cityCenters_nearest`:

# %%
data = data.rename(columns={'cityCenters_nearest':'city_centers_nearest'})
data['city_centers_nearest'].head()
# Out:
# 0    16028.0
# 1    18603.0
# 2    13933.0
# 3     6800.0
# 4     8098.0
# Name: city_centers_nearest, dtype: float64

# %% [markdown]
# Обработаем столбец `ceiling_height` с высотой потолков. Необходимо разобраться с аномальными значениями и пропусками. По ГОСТу (нормативный документ СНиП 31-01-2003) высота потолков может быть не ниже 2.1 метра. Верхняя граница не оговаривается, однако в среднем высота редко превышает 4 метра. Посмотрим сколько значений выходят за рамки этого диапозона:

# %%
print('Число квартир, имеющих потолки выше 4 метров',
        len(data[data['ceiling_height'] > 4]))
print('Число квартир, имеющих потолки ниже 2.1 метров',
        len(data[data['ceiling_height'] < 2.1]))
# Out:
# Число квартир, имеющих потолки выше 4 метров 75
# Число квартир, имеющих потолки ниже 2.1 метров 14

# %%
data.plot(y='ceiling_height', kind='hist', bins=30, range=(0,2.1), grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.plot(y='ceiling_height', kind='hist', bins=30, range=(2.1,4), grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.plot(y='ceiling_height', kind='hist', bins=30, range=(4,100), grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.plot(y='ceiling_height', kind='hist', bins=30, range=(20,40), grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Здорово, что ты используешь range, так нагляднее.
#
# </div>

# %% [markdown]
# 99.9% квартир входит в диапозон значений высоты потолков, указанный в ГОСТ. Есть 23 квартиры с высотой между 20 и 40 метрами, значения которых можно поделить на 10 и заменить. Также есть 11 квартир с высотой ровно 2 метра, которые можно оставить, так как это значение близко к значению по ГОСТ. Остальные квартиры можно отбросить для полной достоверности. Для заполнения пропусков можно воспользоваться медианным значением.

# %%
data['ceiling_height'].describe()
# Out:
# count    14504.000000
# mean         2.771499
# std          1.261056
# min          1.000000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %%
ceiling_height_median = data['ceiling_height'].median()
ceiling_height_median
# Out:
# 2.65

# %%
data['ceiling_height'] = data['ceiling_height'].fillna(ceiling_height_median)
data['ceiling_height'] = data['ceiling_height'].apply(lambda x: x/10 if x >= 20 and x <= 40 else x)
data = data[(data['ceiling_height'] >= 2.0) & (data['ceiling_height'] <= 4)]

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Спасибо, верно обработаны выбивающиеся значения)
#
# </div>

# %% [markdown]
# Проверка полученного результата с помощью гистограмм:

# %%
data.plot(y='ceiling_height', kind='hist', bins=30, range=(0,2.1), grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.plot(y='ceiling_height', kind='hist', bins=30, range=(2.1,4), grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.plot(y='ceiling_height', kind='hist', bins=30, range=(4,100), grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
print(data.isna().mean().sort_values(ascending=False)*100)
print(data.info())
# Out:
# parks_nearest           65.964556
# ponds_nearest           61.612317
# airports_nearest        23.402276
# city_centers_nearest    23.317684
# ponds_around3000        23.313454
# parks_around3000        23.313454
# days_exposition         13.420463
# kitchen_area             9.596921
# living_area              8.023516
# floors_total             0.363744
# locality_name            0.207250
# balcony                  0.000000
# total_images             0.000000
# last_price               0.000000
# studio                   0.000000
# is_apartment             0.000000
# floor                    0.000000
# ceiling_height           0.000000
# rooms                    0.000000
# first_day_exposition     0.000000
# total_area               0.000000
# open_plan                0.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23643 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ...

# %% [markdown]
# Столбцы `locality_name` и `floors_total` содержат малое число пропущенных значений, которое можно отбросить. Посчитаем их:

# %%
print('Число пропущенных значений столбца "locality_name":', data['locality_name'].isna().sum())
print('Число пропущенных значений столбца "floors_total":', data['floors_total'].isna().sum())
# Out:
# Число пропущенных значений столбца "locality_name": 49
# Число пропущенных значений столбца "floors_total": 86

# %% [markdown]
# Отбрасываем и проверяем:

# %%
data = data.dropna(subset=['locality_name', 'floors_total'])
print(data['locality_name'].isna().sum())
print(data['floors_total'].isna().sum())
# Out:
# 0
# 0

# %%
print(data.isna().mean().sort_values(ascending=False)*100)
print(data.info())
# Out:
# parks_nearest           65.978987
# ponds_nearest           61.708282
# airports_nearest        23.459101
# city_centers_nearest    23.374027
# ponds_around3000        23.369773
# parks_around3000        23.369773
# days_exposition         13.454422
# kitchen_area             9.413416
# living_area              7.907610
# locality_name            0.000000
# balcony                  0.000000
# total_images             0.000000
# last_price               0.000000
# studio                   0.000000
# is_apartment             0.000000
# floor                    0.000000
# floors_total             0.000000
# ceiling_height           0.000000
# rooms                    0.000000
# first_day_exposition     0.000000
# total_area               0.000000
# open_plan                0.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23509 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ...

# %% [markdown]
# Проверим столбец `locality_name` на наличие неявных дубликатов:

# %%
data['locality_name'].sort_values().unique()
# Out:
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалёво',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'городской поселок Большая Ижора', 'городской поселок Янино-1',
#        'городской посёлок Будогощь', 'городской посёлок Виллози',
#        'городской посёлок Лесогорский', 'городской посёлок Мга',
#        'городской посёлок Назия', 'городской посёлок Новоселье',
#        'городской посёлок Павлово', 'городской посёлок Рощино',
# ...

# %%
print('число уникальных значений столбца "locality_name" до удаления дубликатов:', 
      data['locality_name'].sort_values().nunique())
# Out:
# число уникальных значений столбца "locality_name" до удаления дубликатов: 364

# %% [markdown]
# Имеются неявные дубликаты по типу "посёлок N" и "поселок N", "посёлок городского типа N", "городской поселок N" и т.п. Так же имеются дубликаты, где нет никаких обозначений посёлка или деревни, например, `Мурино`. Избавимся от неявных дубликатов оставив только названия населённого пункта:

# %%
replace_words = ['поселок городского типа', 'посёлок городского типа', 'городской поселок', 'городской посёлок',
                'посёлок', 'поселок', 'коттеджный', 'коттеджный посёлок', 'коттеджный поселок', 'деревня', 'село',
                'садовое товарищество', 'садоводческое некоммерческое товарищество', 'при железнодорожной станции', 'станции',
                'имени']
for word in replace_words:
    data = data.assign(locality_name = data['locality_name'].str.replace(word, ''))
data = data.assign(locality_name = data['locality_name'].str.strip()) #удаляем незначимые пробелы

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Хорошо, что тобою было замечено разное написание слова «посёлок» и было принято решение это исправить 😃
#
# </div>

# %%
print(data['locality_name'].sort_values().unique())
print('число уникальных значений столбца "locality_name" после удаления дубликатов:',
      data['locality_name'].sort_values().nunique())
# Out:
# ['Агалатово' 'Александровская' 'Алексеевка' 'Аннино' 'Аро' 'Барышево'
#  'Батово' 'Бегуницы' 'Белогорка' 'Белоостров' 'Бокситогорск'
#  'Большая Вруда' 'Большая Ижора' 'Большая Пустомержа' 'Большие Колпаны'
#  'Большое Рейзино' 'Большой Сабск' 'Бор' 'Борисова Грива' 'Бугры'
#  'Будогощь' 'Ваганово' 'Важины' 'Вартемяги' 'Вахнова Кара' 'Вещево'
#  'Виллози' 'Вознесенье' 'Возрождение' 'Войсковицы' 'Войскорово'
#  'Володарское' 'Волосово' 'Волхов' 'Всеволожск' 'Выборг' 'Вырица'
#  'Выскатка' 'Высокоключевой' 'Высоцк' 'Гаврилово' 'Гарболово' 'Гатчина'
#  'Гладкое' 'Глажево' 'Глебычево' 'Глинка' 'Гончарово' 'Горбунки'
#  'Гостилицы' 'Громово' 'Дзержинского' 'Дружная Горка' 'Дружноселье'
#  'Дубровка' 'Елизаветино' 'Ефимовский' 'Жил' 'Жилгородок' 'Житково'
#  'Заводской' 'Заклинье' 'Заневка' 'Запорожское' 'Зеленогорск' 'Зимитицы'
#  'Ивангород' 'Извара' 'Ильичёво' 'Иссад' 'Калитино' 'Каложицы' 'Кальтино'
#  'Каменногорск' 'Камышовка' 'Каськово' 'Келози' 'Кивеннапа Север'
# ...

# %%
print(data.isna().mean().sort_values(ascending=False)*100)
print(data.info())
# Out:
# parks_nearest           65.978987
# ponds_nearest           61.708282
# airports_nearest        23.459101
# city_centers_nearest    23.374027
# ponds_around3000        23.369773
# parks_around3000        23.369773
# days_exposition         13.454422
# kitchen_area             9.413416
# living_area              7.907610
# locality_name            0.000000
# balcony                  0.000000
# total_images             0.000000
# last_price               0.000000
# studio                   0.000000
# is_apartment             0.000000
# floor                    0.000000
# floors_total             0.000000
# ceiling_height           0.000000
# rooms                    0.000000
# first_day_exposition     0.000000
# total_area               0.000000
# open_plan                0.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23509 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ...

# %% [markdown]
# Изучим столбцы `living_area` и `kitchen_area`:

# %%
print(data['total_area'].describe())
print(data['living_area'].describe())
print(data['kitchen_area'].describe())
# Out:
# count    23509.000000
# mean        60.149919
# std         35.031089
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.500000
# max        900.000000
# Name: total_area, dtype: float64
# count    21650.000000
# mean        34.349558
# std         21.659366
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.200000
# max        409.700000
# Name: living_area, dtype: float64
# count    21296.000000
# mean        10.544260
# std          5.866392
# min          1.300000
# 25%          7.000000
# 50%          9.100000
# 75%         12.000000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Пропуски в данных есть для столбцов с жилой площадью и кухонной площадью, однако в столбце общей площади пропусков нет. Можно посчитать медианное значение отношения жилой и кухонной площадей к общей площади:

# %%
ratio_living_median = (data['living_area']/data['total_area']).median()
print(ratio_living_median)
# Out:
# 0.5681818181818181

# %%
ratio_kitchen_median = (data['kitchen_area']/data['total_area']).median()
print(ratio_kitchen_median)
# Out:
# 0.17239110707803992

# %% [markdown]
# Затем заполнить пропуски в `living_area` и `kitchen_area` медианным значением оношения, умноженным на значение полной площади объекта:

# %%
data['living_area'] = data['living_area'].fillna(data['total_area']*ratio_living_median).round(1)

# %%
data['living_area']
# Out:
# 0        51.0
# 1        18.6
# 2        34.3
# 3        90.3
# 4        32.0
#          ...
# 23694    73.3
# 23695    38.0
# 23696    29.7
# 23697    43.6
# 23698    12.3
# Name: living_area, Length: 23509, dtype: float64

# %%
data['living_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# Повтори, пожалуйста, спринт «Предобработка данных» тему «Категоризация данных» урок «Функция для одной строки» и примени метод apply, он создан для того, чтобы работать со строками в pandas, ходить циклом по df очень долго и это очень плохая практика.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента</font></h5>
#
# Повторил предобработку данных и применил метод `fillna()` для замены пропущенных значений.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍
#
# Спасибо, так еще лучше)
#
# </div>

# %%
data['kitchen_area'] = data['kitchen_area'].fillna(data['total_area']*ratio_kitchen_median).round(1)

# %%
data['kitchen_area']
# Out:
# 0        25.0
# 1        11.0
# 2         8.3
# 3        27.4
# 4        41.0
#          ...
# 23694    13.8
# 23695     8.5
# 23696     9.8
# 23697    23.3
# 23698     9.0
# Name: kitchen_area, Length: 23509, dtype: float64

# %%
data['kitchen_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Пропуски заполнены корректно 😃
#
# </div>

# %%
print(data.isna().mean().sort_values(ascending=False)*100)
# Out:
# parks_nearest           65.978987
# ponds_nearest           61.708282
# airports_nearest        23.459101
# city_centers_nearest    23.374027
# ponds_around3000        23.369773
# parks_around3000        23.369773
# days_exposition         13.454422
# last_price               0.000000
# locality_name            0.000000
# balcony                  0.000000
# kitchen_area             0.000000
# total_images             0.000000
# studio                   0.000000
# is_apartment             0.000000
# floor                    0.000000
# living_area              0.000000
# floors_total             0.000000
# ceiling_height           0.000000
# rooms                    0.000000
# first_day_exposition     0.000000
# total_area               0.000000
# open_plan                0.000000
# dtype: float64

# %% [markdown]
# Пропущенные значения площадей были заполнены успешно.

# %% [markdown]
# Также можно поменять тип данных столбца `last_price` на `int64`:

# %%
data = data.assign(last_price = data['last_price'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23509 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23509 non-null  int64
#  1   last_price            23509 non-null  float64
#  2   total_area            23509 non-null  float64
#  3   first_day_exposition  23509 non-null  datetime64[ns]
#  4   rooms                 23509 non-null  int64
#  5   ceiling_height        23509 non-null  float64
#  6   floors_total          23509 non-null  float64
#  7   living_area           23509 non-null  float64
#  8   floor                 23509 non-null  int64
#  9   is_apartment          23509 non-null  bool
#  10  studio                23509 non-null  bool
#  11  open_plan             23509 non-null  bool
#  12  kitchen_area          23509 non-null  float64
#  13  balcony               23509 non-null  float64
# ...

# %% [markdown]
# Одинаковое множество пропущенных значений в столбцах с данными о количестве прудов и парков в районе 3000 метров от объекта. Проверим уникальные значения:

# %%
print(data['parks_around3000'].unique())
print(data['ponds_around3000'].unique())
# Out:
# [ 1.  0.  2. nan  3.]
# [ 2.  0.  3.  1. nan]

# %% [markdown]
# Можно заменить пропущенные значения на 0, однако нужно проверить, будет ли указано расстояние до ближайшего пруда или парка в случае нулевого значения количества прудов и парков в радиусе 3000 метров от объекта:

# %%
data_zero_parks_and_ponds = data[(data['parks_around3000'] == 0.) & (data['ponds_around3000'] == 0.)]

# %%
data_zero_parks_and_ponds.plot(y='parks_nearest', kind='hist', bins=100, range=(0,3000), grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data_zero_parks_and_ponds.plot(y='ponds_nearest', kind='hist', bins=100, range=(0,3000), grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data_non_zero_parks_and_ponds = data[(data['parks_around3000'] != 0.) & (data['ponds_around3000'] != 0.)]

# %%
data_non_zero_parks_and_ponds.plot(y='parks_nearest', kind='hist', bins=100, range=(0,3000), grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data_non_zero_parks_and_ponds.plot(y='ponds_nearest', kind='hist', bins=100, range=(0,3000), grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data = data.assign(parks_around3000 = data['parks_around3000'].fillna(0))
data = data.assign(ponds_around3000 = data['ponds_around3000'].fillna(0))

# %%
print(data.isna().mean().sort_values(ascending=False)*100)
# Out:
# parks_nearest           65.978987
# ponds_nearest           61.708282
# airports_nearest        23.459101
# city_centers_nearest    23.374027
# days_exposition         13.454422
# last_price               0.000000
# ponds_around3000         0.000000
# parks_around3000         0.000000
# locality_name            0.000000
# balcony                  0.000000
# kitchen_area             0.000000
# total_images             0.000000
# studio                   0.000000
# is_apartment             0.000000
# floor                    0.000000
# living_area              0.000000
# floors_total             0.000000
# ceiling_height           0.000000
# rooms                    0.000000
# first_day_exposition     0.000000
# total_area               0.000000
# open_plan                0.000000
# dtype: float64

# %%
print('Число пропусков в столбце "parks_nearest":', data['parks_nearest'].isna().sum())
# Out:
# Число пропусков в столбце "parks_nearest": 15511

# %%
print('Число пропусков в столбце "ponds_nearest":', data['ponds_nearest'].isna().sum())
# Out:
# Число пропусков в столбце "ponds_nearest": 14507

# %%
k = 0
isnamask = data.isna()
for i in data.index:
    if (isnamask.loc[i, 'parks_nearest'] == True) and (data.loc[i, 'parks_around3000'] == 0.0):
            k += 1
            
print('Число пропусков в столбце "parks_nearest", для которых parks_around3000 = 0:', k)
# Out:
# Число пропусков в столбце "parks_nearest", для которых parks_around3000 = 0: 15511

# %%
k2 = 0
for i in data.index:
    if (isnamask.loc[i, 'ponds_nearest'] == True) and (data.loc[i, 'ponds_around3000'] == 0.0):
            k2 += 1
            
print('Число пропусков в столбце "ponds_nearest", для которых ponds_around3000 = 0:', k2)
# Out:
# Число пропусков в столбце "ponds_nearest", для которых ponds_around3000 = 0: 14507

# %%
data = data.assign(ponds_nearest = data['ponds_nearest'].fillna(3001))
data = data.assign(parks_nearest = data['parks_nearest'].fillna(3001))

# %%
print(data.isna().mean().sort_values(ascending=False)*100)
# Out:
# airports_nearest        23.459101
# city_centers_nearest    23.374027
# days_exposition         13.454422
# last_price               0.000000
# ponds_nearest            0.000000
# ponds_around3000         0.000000
# parks_nearest            0.000000
# parks_around3000         0.000000
# locality_name            0.000000
# balcony                  0.000000
# kitchen_area             0.000000
# total_images             0.000000
# studio                   0.000000
# is_apartment             0.000000
# floor                    0.000000
# living_area              0.000000
# floors_total             0.000000
# ceiling_height           0.000000
# rooms                    0.000000
# first_day_exposition     0.000000
# total_area               0.000000
# open_plan                0.000000
# dtype: float64

# %%
data[data['ponds_nearest'] < 3000]['ponds_nearest'].describe()
# Out:
# count    9002.000000
# mean      518.412575
# std       278.126390
# min        13.000000
# 25%       293.000000
# 50%       503.000000
# 75%       730.750000
# max      1344.000000
# Name: ponds_nearest, dtype: float64

# %%
data_locations = data.pivot_table(index='locality_name', values=['airports_nearest', 'city_centers_nearest'], aggfunc=['median', 'count'])
print(data_locations[data_locations['count', 'airports_nearest'] == 0].count())
print(data_locations[data_locations['count', 'airports_nearest'] > 0].count())
# Out:
# median  airports_nearest          0
#         city_centers_nearest      0
# count   airports_nearest        280
#         city_centers_nearest    280
# dtype: int64
# median  airports_nearest        25
#         city_centers_nearest    25
# count   airports_nearest        25
#         city_centers_nearest    25
# dtype: int64

# %% [markdown]
# Для 25 из 305 населённых пунктов указано расстояние до центра города и до аэропорта. Таким образом заполнить медианными значениями пропуски для каждого города не получится. Оставим пропуски в этих столбцах.

# %% [markdown]
# Пропуски в столбце `days_exposition` скорее всего связаны с тем, что квартира висит в продаже. Заполнять эти пропуски нет необходимости.

# %% [markdown]
# **Предобработка данных завершена.**

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h5>
#
# Очень качественно подготовлены данные для дальнейшего исследования, но нет промежуточных выводов.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента</font></h5>
#
# Выводы добавлены ниже:
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍
#
# </div>

# %% [markdown]
# **Промежуточные выводы:**
#
# - Заменены неявные дубликаты (раньше названия населенных пунктов повторялись из-за разной записи).
# - Столбец с датой приведен к округленному до дней и правильному форматам.
# - Пропуски в столбце с высотой потолков заменены медианным значением.
# - Замена на булев тип данных в столбцах, где это необходимо.
# - Пропуски в kitchen area исправлены на значение равное 17.2% от общей площади квартиры, что является медианным значением. - - - - Пропуски в living area исправлены на значение равное 56.8% от общей площади квартиры, что является медианным значением.
# - Было выявлено, что пропуски в данных с количеством парков и прудов в радиусе 3000 метров означали отсутсвие таковых в данном радиусе. Пропуски были заменены на значение 3001.

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
# Добавим в датасет столбец с ценой за один квадратный метр:

# %%
data = data.assign(price_for_square_meter = data['last_price']/data['total_area'])
data['price_for_square_meter']
# Out:
# 0        120370.370370
# 1         82920.792079
# 2         92785.714286
# 3        408176.100629
# 4        100000.000000
#              ...
# 23694     72490.845228
# 23695     52542.372881
# 23696     44091.710758
# 23697    149511.400651
# 23698     41795.665635
# Name: price_for_square_meter, Length: 23509, dtype: float64

# %% [markdown]
# Добавим в датасет столбец с расстоянием до центра города, выраженном в километрах:

# %%
data = data.assign(city_centers_nearest_km = data['city_centers_nearest']/1000)
data['city_centers_nearest_km'] = data['city_centers_nearest_km'].round(1)
data['city_centers_nearest_km']
# Out:
# 0        16.0
# 1        18.6
# 2        13.9
# 3         6.8
# 4         8.1
#          ...
# 23694     4.2
# 23695     NaN
# 23696     NaN
# 23697    10.4
# 23698     NaN
# Name: city_centers_nearest_km, Length: 23509, dtype: float64

# %% [markdown]
# Добавим в датасет столбец с расстоянием до ближайшего аэропорта, выраженном в километрах:

# %%
data = data.assign(airports_nearest_km = data['airports_nearest']/1000)
data['airports_nearest_km'] = data['airports_nearest_km'].round(1)
data['airports_nearest_km']
# Out:
# 0        18.9
# 1        12.8
# 2        21.7
# 3        28.1
# 4        31.9
#          ...
# 23694    24.7
# 23695     NaN
# 23696     NaN
# 23697    39.1
# 23698     NaN
# Name: airports_nearest_km, Length: 23509, dtype: float64

# %% [markdown]
# Добавим в датасет столбцы с днем, месяцем и годом публикации объявления по отдельности:

# %%
data = data.assign(day_of_publication = data['first_day_exposition'].dt.day)
data = data.assign(month_of_publication = data['first_day_exposition'].dt.month_name())
data = data.assign(month_of_publication_id = data['first_day_exposition'].dt.month)
data = data.assign(year_of_publication = data['first_day_exposition'].dt.year)
data[['day_of_publication', 'month_of_publication', 'month_of_publication_id', 'year_of_publication']]
# Out:
#        day_of_publication month_of_publication  month_of_publication_id  \
# 0                       7                March                        3
# 1                       4             December                       12
# 2                      20               August                        8
# 3                      24                 July                        7
# 4                      19                 June                        6
# ...                   ...                  ...                      ...
# 23694                  21                March                        3
# 23695                  15              January                        1
# 23696                  11             February                        2
# 23697                  28                March                        3
# 23698                  21                 July                        7
#
#        year_of_publication
# 0                     2019
# 1                     2018
# ...

# %% [markdown]
# Добавим в датасет столбец с категоризацией этажа объекта:

# %%
def floor(row):
    if row['floor'] == 1:
        return 'первый'
    if row['floor'] == row['floors_total']:
        return 'последний'
    else:
        return 'другой'

data['floor_id'] = data.apply(floor, axis=1)
data[['floor', 'floors_total', 'floor_id']].head(20)
# Out:
#     floor  floors_total   floor_id
# 0       8          16.0     другой
# 1       1          11.0     первый
# 2       4           5.0     другой
# 3       9          14.0     другой
# 4      13          14.0     другой
# 5       5          12.0     другой
# 6       6          26.0     другой
# 7      22          24.0     другой
# 8      26          27.0     другой
# 9       7           9.0     другой
# 10      3          12.0     другой
# 11      4           5.0     другой
# 12      5           5.0  последний
# 13      5           5.0  последний
# 14      1           6.0     первый
# 15      5          14.0     другой
# 16      1           5.0     первый
# 17      7          17.0     другой
# 18      2           5.0     другой
# 19      8          16.0     другой

# %% [markdown]
# Выведем датасет для проверки:

# %%
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00           2019-03-07      3
# 1                 7   3350000.0       40.40           2018-12-04      1
# 2                10   5196000.0       56.00           2015-08-20      2
# 3                 0  64900000.0      159.00           2015-07-24      3
# 4                 2  10000000.0      100.00           2018-06-19      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81           2017-03-21      3
# 23695            14   3100000.0       59.00           2018-01-15      3
# 23696            18   2500000.0       56.70           2018-02-11      2
# 23697            13  11475000.0       76.75           2017-03-28      2
# 23698             4   1350000.0       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23509 entries, 0 to 23698
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   total_images             23509 non-null  int64
#  1   last_price               23509 non-null  float64
#  2   total_area               23509 non-null  float64
#  3   first_day_exposition     23509 non-null  datetime64[ns]
#  4   rooms                    23509 non-null  int64
#  5   ceiling_height           23509 non-null  float64
#  6   floors_total             23509 non-null  float64
#  7   living_area              23509 non-null  float64
#  8   floor                    23509 non-null  int64
#  9   is_apartment             23509 non-null  bool
#  10  studio                   23509 non-null  bool
#  11  open_plan                23509 non-null  bool
#  12  kitchen_area             23509 non-null  float64
#  13  balcony                  23509 non-null  float64
# ...

# %% [markdown]
# Преобразуем тип данных для некоторых столбцов:

# %%
data['is_apartment'] = data['is_apartment'].astype('bool')
data['last_price'] = data['last_price'].astype('int')
data['balcony'] = data['balcony'].astype('int')
data['floors_total'] = data['floors_total'].astype('int')
data['parks_around3000'] = data['floors_total'].astype('int')
data['ponds_around3000'] = data['floors_total'].astype('int')

# %% [markdown]
# Проверим преобразование:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23509 entries, 0 to 23698
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   total_images             23509 non-null  int64
#  1   last_price               23509 non-null  int64
#  2   total_area               23509 non-null  float64
#  3   first_day_exposition     23509 non-null  datetime64[ns]
#  4   rooms                    23509 non-null  int64
#  5   ceiling_height           23509 non-null  float64
#  6   floors_total             23509 non-null  int64
#  7   living_area              23509 non-null  float64
#  8   floor                    23509 non-null  int64
#  9   is_apartment             23509 non-null  bool
#  10  studio                   23509 non-null  bool
#  11  open_plan                23509 non-null  bool
#  12  kitchen_area             23509 non-null  float64
#  13  balcony                  23509 non-null  int64
# ...

# %% [markdown]
# **Готово. Можно переходить к исследовательскому анализу.**

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Молодец, корректно созданы дополнительные столбцы с необходимыми метриками.
#
# </div>

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# Построим и изучим гистограммы для основных параметров датафрейма. Получим статистические данные методом describe():

# %%
print(data[['total_area', 'living_area', 'kitchen_area', 'last_price', 'rooms', 'floor', 'floors_total',
           'city_centers_nearest_km', 'airports_nearest_km', 'day_of_publication',
           'month_of_publication_id', 'year_of_publication', 'ceiling_height']].describe())
print(data[data['parks_nearest'] < 3000]['parks_nearest'].describe())
print(data[data['ponds_nearest'] < 3000]['ponds_nearest'].describe())
# Out:
#          total_area   living_area  kitchen_area    last_price         rooms  \
# count  23509.000000  23509.000000  23509.000000  2.350900e+04  23509.000000
# mean      60.149919     34.466043     10.465907  6.490621e+06      2.068612
# std       35.031089     21.961891      5.980158  1.073583e+07      1.075947
# min       12.000000      2.000000      1.300000  1.219000e+04      0.000000
# 25%       40.000000     19.000000      7.000000  3.400000e+06      1.000000
# 50%       52.000000     30.000000      9.000000  4.610000e+06      2.000000
# 75%       69.500000     42.000000     12.000000  6.750000e+06      3.000000
# max      900.000000    409.700000    112.000000  7.630000e+08     19.000000
#
#               floor  floors_total  city_centers_nearest_km  \
# count  23509.000000  23509.000000             18014.000000
# mean       5.880812     10.685099                14.212340
# std        4.873122      6.593885                 8.609996
# ...

# %%
display(data.plot(y='total_area', kind='hist', bins=100, range=(0,300), grid=True))
display(data.plot(y='living_area', kind='hist', bins=100, range=(0,200), grid=True))
display(data.plot(y='kitchen_area', kind='hist', bins=60, range=(0,60), grid=True))
display(data.plot(y='last_price', kind='hist', bins=100, range=(0,30000000), grid=True))
display(data.plot(y='rooms', kind='hist', bins=20, range=(0,10), grid=True))
display(data.plot(y='floor', kind='hist', bins=30, range=(0,30), grid=True))
display(data.plot(y='floors_total', kind='hist', bins=40, range=(0,40), grid=True))
display(data.plot(y='city_centers_nearest_km', kind='hist', bins=60, range=(0,60), grid=True))
display(data.plot(y='airports_nearest_km', kind='hist', bins=60, range=(0,60), grid=True))
display(data.plot(y='day_of_publication', kind='hist', bins=31, range=(0,31), grid=True))
display(data.plot(y='month_of_publication_id', kind='hist', bins=12, range=(0,12), grid=True))
display(data.plot(y='year_of_publication', kind='hist', bins=6, range=(2014,2020), grid=True))
display(data.plot(y='ceiling_height', kind='hist', bins=50, range=(2.0,4.0), grid=True))
display(data.plot(y='parks_nearest', kind='hist', bins=100, range=(0,3000), grid=True))
display(data.plot(y='ponds_nearest', kind='hist', bins=100, range=(0,3000), grid=True))
# Out:
# <AxesSubplot:ylabel='Frequency'>
# <AxesSubplot:ylabel='Frequency'>
# <AxesSubplot:ylabel='Frequency'>
# <AxesSubplot:ylabel='Frequency'>
# <AxesSubplot:ylabel='Frequency'>
# <AxesSubplot:ylabel='Frequency'>
# <AxesSubplot:ylabel='Frequency'>
# <AxesSubplot:ylabel='Frequency'>
# <AxesSubplot:ylabel='Frequency'>
# <AxesSubplot:ylabel='Frequency'>
# <AxesSubplot:ylabel='Frequency'>
# <AxesSubplot:ylabel='Frequency'>
# <AxesSubplot:ylabel='Frequency'>
# <AxesSubplot:ylabel='Frequency'>
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Красивое построение и выводы правильные, молодец 😃
#
# </div>

# %% [markdown]
# **Выводы:**
#
# **Общая площадь:** Значения лежат в диапозоне от 12 до 900 м2. Среднее значение 60 м2, медианное значение 52 м2. Данные распределены нормально, пикующие значения наблюдаются в области 35-40 м2 и 55-60 м2 - средние площади одно- и двухкомнатных квартир.
#
# **Жилая площадь:** Значения лежат в диапозоне от 2 до 410 м2. Среднее значение 34 м2, медианное значение 30 м2. Данные распределены нормально, пикующие значения наблюдаются в области 15-20 м2 и 28-30 м2 - средние жилые площади одно- и двухкомнатных квартир. Есть редкие выбросы в районе 40-43 м2, не влияющие на данные. Нижняя граница составляет 2 м2 при нижней границе общей площади 12 м2, что может говорить о некоторой некорректности данных в области нижних границ распределения, однако таких значений мало по отношению к общему числу данных. Возможно в данных содержится информация о нежилых помещениях типа гаража или кладовки.
#
# **Кухонная площадь:** Значения лежат в диапозоне от 1.3 до 112 м2. Среднее значение 10.4 м2, медианное значение 9 м2. Данные распределены нормально, пикующие значения наблюдаются в областях 5, 7 и 11 м2. Нижняя граница составляет 1 м2 при нижней границе общей площади 12 м2, что может говорить о некоторой некорректности данных в области нижних границ распределения, однако таких значений мало по отношению к общему числу данных. Возможно в данных содержится информация о нежилых помещениях типа гаража или кладовки.
#
# **Цена объекта в объявлении:** Значения лежат в диапозоне от 12190 до 763000000. Среднее значение 6490621, медианное значение 4610000. Данные распределены нормально, явных пикующих значений не обнаружено.
#
# **Количество комнат:** Значения лежат в диапозоне от 0 до 19. Среднее значение 2, медианное значение 2. Данные распределены нормально. Большинство объектов имеют одну или две комнаты. Есть объекты, которые не содержат комнат, что еще раз говорит о содержании нежилых помещений в данных.
#
# **Этаж объекта:** Значения лежат в диапозоне от 1 до 33. Среднее значение 6, медианное значение 4. Данные можно описать экспоненциально с пороговым значением в районе 1. Большинство объектов находятся в диапозоне от 1 до 5 этажа, далее распределение убывает.
#
# **Число этажей в доме объекта:** Значения лежат в диапозоне от 1 до 60. Среднее значение 11, медианное значение 9. Основные пики наблюдаются в значениях 5 и 9 этажей. Менее пикующие значения: 13, 17 и 26 этажей.
#
# **Расстояние от объекта до центра города:** Значения лежат в диапозоне от 0.2 до 66 км. Среднее значение 14.2 км, медианное значение 13.1 км. Имеется явный провал в данных в диапозоне 6-10 км, что создаёт два пика по обеим сторонам от провала.
#
# **Расстояние от объекта до ближайшего аэропорта:** Значения лежат в диапозоне от 0 до 84.9 км. Среднее значение 28.8 км, медианное значение 26.8 км. Данные распределены по всему диапозону с множеством пиков, с возрастанием значением распределение убывает. Есть аномальные значения в районе 0, которое можно отбросить.
#
# **День публикации объявления:** Значения лежат в ожидаемом диапозоне от 1 до 31 числа месяца. Среднее значение 15, медианное значение 15. Существуют выбросы в значениях 1 числа месяца и 10 числа месяца - наиболее популярные дни публикаций объявления.
#
# **Месяц публикации объявления:** Значения лежат в ожидаемом диапозоне от 1 до 12. Среднее значение 6, медианное значение 6. Существуют выбросы в значении 12 - наибольшее число объявлений публикуется в конце года. Наименьшие значения 1 и 5 - в январе и мае.
#
# **Год публикации объявления:** Значения лежат в ожидаемом диапозоне от 2014 до 2019 года. Среднее значение 2017, медианное значение 2017. Платфома Яндекс.Недвижимость набирала популярность с каждым годом - число публикаций год к году росло. Данные для 2019 года неполные - до мая 2019 года, поэтому наблюдается провал. Данные для 2014 года также неполные и начинаются с ноября.
#
# **Высота потолков**: Значения лежат в диапозоне от 2 до 4 м, так как остальные аномальные значения были ранее отброшены. Среднее значение 2.69 м, медианное значение 2.65 м. Наблюдаются явные пики в значениях 2.5 и 2.65 (медиана) метров.
#
# **Расстояние от объекта до ближайшего парка:** Значения исследовались в диапозоне от 0 до 3000 метров. Распределение лежит в диапозоне от 1 до 2984 м. Среднее значение 489 м, медианное значение 454 м. Распределение нормальное с редкими выбросами после 1000 м.
#
# **Расстояние от объекта до ближайшего пруда:** Значения исследовались в диапозоне от 0 до 3000 метров. Распределение лежит в диапозоне от 13 до 1344 м. Среднее значение 518.4 м, медианное значение 503 м. Распределение нормальное.

# %% [markdown]
# **Исследуем как быстро продавались квартиры:**

# %%
plt.boxplot(data[data['days_exposition']>0]['days_exposition'])
plt.ylim(1,1000)

data.plot(y = 'days_exposition', kind = 'hist', bins = 30, grid = True, range = (1,1600))
data.plot(y = 'days_exposition', kind = 'hist', bins = 100, grid = True, range = (1,231))

display('Среднее значение с квартилями', data[data['days_exposition']!=0]['days_exposition'].describe())
display('Медиана',
        data[data['days_exposition']!=0]['days_exposition'].median())
display('Выбивающиеся значения',
        data[data['days_exposition']!=0]['days_exposition'].value_counts())
# Out:
# 'Среднее значение с квартилями'
# count    20346.000000
# mean       180.461762
# std        219.428537
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64
# 'Медиана'
# 95.0
# 'Выбивающиеся значения'
# 45.0      879
# 60.0      537
# 7.0       234
# 30.0      207
# 90.0      200
#          ...
# 969.0       1
# 1147.0      1
# 1148.0      1
# 1345.0      1
# 1174.0      1
# Name: days_exposition, Length: 1138, dtype: int64

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h5>
#
# Молодец, верно интерпретированы данные из графика и .describe() 😃
#
# Стоит загружать все библиотеки в начале проекта, лучше в одной ячейке. Так тебе будет сложней случайно удалить ячейку с загрузкой нужной библиотеки и сделать код не работающим. А получатель твоего отчета сразу поймет, какие библиотеки ты используешь и какие ему нужно установить для запуска твоего проекта.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента</font></h5>
#
# Перенёс объявление в начало проекта в ячейку, где объявляю pandas
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍
#
# </div>

# %% [markdown]
# На данных графиках видно, что распределение равномерное, с редкими выбросами. Среднее значение равняется 180 дням, а медиана равна 95 дням. Выявлены выбивающиеся значения и методом value_counts подтверждаем это - аномалии находятся на 45, 60, 7, 30, 90 днях. Данные аномалии связаны с тем, что сроки публикации на яндексе соответсвуют этим дням.
#
# - Продажа комнаты - 45 дней
# - Продажа дома, участка или гаража - 90 дней
# - Аренда комнаты - 7 дней
# - Аренда комнаты, участка или гаража - 30 дней
# - Аренда и продажа коммерческого объекта - 60 дней
# - Продажа квартиры: до 4,5 млн — 45 дней, от 4,5 до 10 млн — 60 дней, от 10 млн — 90 дней
# - Аренда квартиры: до 20 тыс/м — 7 дней, от 20 до 40 тыс/м — 14 дней, от 40 тыс/м — 21 день
# - Аренда посуточная: Квартира, Комната, Дом / участок, Гараж - 60 дней.
#
# На графике boxplot видно, что "нормальные" данные находятся в диапазоне 1 - 231, выбросы находятся на отметке 500 дней и больше.
#
# **Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?** -
# Публикации снятые в первый день - являются быстрыми, те, что держатся 500 дней и больше - необычно долго.
#
# **Уберите редкие и выбивающиеся значения.** -
# Можно убрать значения, где квартиры продаются 500 дней и больше.

# %%
print('Квартиры, продающиеся больше 500 дней (%)', len(data.query('days_exposition > 500'))/len(data)*100)
# Out:
# Квартиры, продающиеся больше 500 дней (%) 7.354630141647879

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Молодец, перед отбросом выбросов очень важно в процентах оценить, сколько мы теряем, должно быть не более 10%.
#
# </div>

# %% [markdown]
# Число квартир, продающихся более 500 дней составляет порядка 7.35 % - отбросим эти значения, обновим индексы и выведем датафрейм на экран:

# %%
data = data[data['days_exposition'] < 500]
data = data.reset_index(drop=True)
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                 7     3350000        40.4           2018-12-04      1
# 1                 0    64900000       159.0           2015-07-24      3
# 2                 2    10000000       100.0           2018-06-19      2
# 3                10     2890000        30.4           2018-09-10      1
# 4                 6     3700000        37.3           2017-11-02      1
# ...             ...         ...         ...                  ...    ...
# 18607            13     3550000        35.3           2018-02-28      1
# 18608             3     5500000        52.0           2018-07-19      2
# 18609             2     1350000        30.0           2017-07-07      1
# 18610             9     4600000        62.4           2016-08-05      3
# 18611            14     3100000        59.0           2018-01-15      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# ...

# %% [markdown]
# **Исследование зависимости цены от площади, числа комнат, удалённости от центра, этажности и даты размещения.**

# %% [markdown]
# a) ЗАВИСИМОСТЬ ЦЕНЫ ОТ ОБЩЕЙ ПЛОЩАДИ ОБЪЕКТА

# %%
data_total_area = data.pivot_table(index = 'total_area', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
#Сводная таблица с данными цены объекта в зависимости от площади объекта.
data_total_area.columns = ['mean', 'count', 'median'] 
display(data_total_area.query('count > 40').sort_values('median', ascending = False))
data_total_area.query('count > 40').plot(y = 'median') #не включаем единичные случаи, чтобы картина была правдоподобнее
display(data_total_area)
print('Коэффициент корреляции Пирсона:', data['total_area'].corr(data['last_price']))
data.plot(x = 'total_area', y = 'last_price', kind='scatter', alpha=0.06, xlim=(0,500), ylim=(0,90000000))
# Out:
#                     mean  count      median
# total_area
# 100.0       1.228425e+07     48  12025000.0
# 95.0        9.889113e+06     45   9800000.0
# 90.0        1.070708e+07     60   8775000.0
# 85.0        9.015031e+06     59   8600000.0
# 77.0        8.413532e+06     47   7500000.0
# 83.0        8.524802e+06     42   7420000.0
# 80.0        8.024100e+06    124   7250000.0
# 79.0        7.487749e+06     50   7225000.0
# 78.0        7.502286e+06     62   7025000.0
# 70.0        7.279643e+06    152   6945000.0
# 75.0        7.321029e+06     97   6800000.0
# 82.0        7.718349e+06     45   6700000.0
# 76.0        7.234774e+06     62   6562500.0
# 71.0        6.747158e+06     57   6500000.0
# 72.0        6.816357e+06    142   6497500.0
# 69.0        6.539323e+06     65   6300000.0
# 67.0        6.066320e+06     96   6300000.0
# 68.0        6.653952e+06     88   6200000.0
# 66.0        6.228231e+06     75   6200000.0
# 73.0        6.086378e+06     68   6000000.0
# ...

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# Полный вывод, правильно посчитана и интерпретирована корреляция.
#
# Построй, пожалуйста, график из спринта «Исследовательский анализ данных», урока «Взаимосвязь данных», темы «Корреляция» для основных факторов.
#
#
# </div>

# %% [markdown]
# На графике корреляции видна зависисмость между ценой и общей площадью объекта. Цена возрастает с увеличением общей площади.
# Коэффицент корреляции Пирсона равен 0.621, что говорит о достаточно высокой корреляции между общей площадью и ценой. График зависимости цены от общей площади так же отражает положительную корреляцию. Основная плотность числа объявлений находится в дипазоне 0-120 м2 по общей площади и 0-18000000 по цене объекта.

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента</font></h5>
#
# Построил график типа scatterplot, добавил вывод. Тоже самое сделал и для остальных исследуемых количественных переменных.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ График построен верно, спасибо, что добавлена прозрачность, так нагляднее.
#
# </div>

# %% [markdown]
# b) ЗАВИСИМОСТЬ ЦЕНЫ ОТ ЖИЛОЙ ПЛОЩАДИ ОБЪЕКТА

# %%
data_living_area = data.pivot_table(index = 'living_area', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
#Сводная таблица с данными цены объекта в зависимости от площади объекта.
data_living_area.columns = ['mean', 'count', 'median'] 
display(data_living_area.query('count > 40').sort_values('median', ascending = False))
data_living_area.query('count > 40').plot(y = 'median') #не включаем единичные случаи, чтобы картина была правдоподобнее
display(data_living_area)
print('Коэффициент корреляции Пирсона:', data['living_area'].corr(data['last_price']))
data.plot(x = 'living_area', y = 'last_price', kind='scatter', alpha=0.06, xlim=(0,350), ylim=(0,90000000))
# Out:
#                      mean  count      median
# living_area
# 60.0         1.386062e+07     47  11900000.0
# 55.0         9.900588e+06     51   9300000.0
# 53.0         9.055190e+06     63   8500000.0
# 51.0         8.852024e+06     42   8250000.0
# 54.0         9.527318e+06     61   8200000.0
# ...                   ...    ...         ...
# 15.3         3.557217e+06     47   3290000.0
# 17.0         3.339987e+06    592   3250000.0
# 15.5         3.413952e+06     62   3210000.0
# 17.6         3.259807e+06    114   3200000.0
# 17.2         3.179838e+06     79   3050000.0
#
# [97 rows x 3 columns]
#                     mean  count       median
# living_area
# 2.0            4340000.0      2    4340000.0
# 3.0           34715000.0      2   34715000.0
# 5.0            2680000.0      1    2680000.0
# 5.4            6100000.0      1    6100000.0
# 6.0            3799000.0      1    3799000.0
# ...                  ...    ...          ...
# 284.1        190000000.0      2  190000000.0
# ...

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# Нет таблицы `data_area`.
#
# Перед отправкой проекта стоит проверять работоспособность кода — это можно сделать, нажав на панели Jupiter Hub ``Kernel`` и ``Restart & Run All`` (см скриншот ниже).
# ![](https://i.postimg.cc/yd19rYf6/Screenshot-428.png)
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента</font></h5>
#
# Поправил код, ошибок большк не должно быть
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍
#
# </div>

# %% [markdown]
# На графике корреляции видна зависисмость между ценой и жилой площадью объекта. Цена возрастает с увеличением жилой площади.
# Коэффицент корреляции Пирсона равен 0.549, что говорит о достаточно высокой корреляции между жилой площадью и ценой. График зависимости цены от жилой площади так же отражает положительную корреляцию. Основная плотность числа объявлений находится в дипазоне 0-70 м2 по жилой площади и 0-16000000 по цене объекта.

# %% [markdown]
# c) ЗАВИСИМОСТЬ ЦЕНЫ ОТ КУХОННОЙ ПЛОЩАДИ ОБЪЕКТА

# %%
data_kitchen_area = data.pivot_table(index = 'kitchen_area', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
#Сводная таблица с данными цены объекта в зависимости от площади объекта.
data_kitchen_area.columns = ['mean', 'count', 'median'] 
display(data_kitchen_area.query('count > 40').sort_values('median', ascending = False))
data_kitchen_area.query('count > 40').plot(y = 'median') #не включаем единичные случаи, чтобы картина была правдоподобнее
display(data_kitchen_area)
print('Коэффициент корреляции Пирсона:', data['kitchen_area'].corr(data['last_price']))
data.plot(x = 'kitchen_area', y = 'last_price', kind='scatter', alpha=0.06, xlim=(0,100), ylim=(0,90000000))
# Out:
#                       mean  count      median
# kitchen_area
# 25.0          1.537733e+07     42  11200000.0
# 20.0          1.565514e+07     99  10000000.0
# 19.0          1.245344e+07     48   9875000.0
# 17.0          1.009128e+07     92   8806000.0
# 18.0          1.134327e+07     74   8500000.0
# ...                    ...    ...         ...
# 5.3           3.131275e+06    160   3095000.0
# 5.5           3.100364e+06    343   3050000.0
# 4.8           3.135134e+06     41   2980000.0
# 4.7           2.778146e+06     41   2890000.0
# 4.0           2.922805e+06     44   2575000.0
#
# [99 rows x 3 columns]
#                       mean  count       median
# kitchen_area
# 2.0           2.821429e+06      7    2720000.0
# 2.1           2.400000e+06      1    2400000.0
# 2.2           2.350000e+06      3    1850000.0
# 2.3           2.313000e+06      2    2313000.0
# 2.4           2.200000e+06      1    2200000.0
# ...                    ...    ...          ...
# ...

# %% [markdown]
# На графике корреляции видна зависисмость между ценой и кухонной площадью объекта. Цена возрастает с увеличением кухонной площади. Коэффицент корреляции Пирсона равен 0.477, что говорит о достаточно высокой корреляции между кухонной площадью и ценой. График зависимости цены от кухонной площади так же отражает положительную корреляцию. Основная плотность числа объявлений находится в дипазоне 0-21 м2 по кухонной площади и 0-16000000 по цене объекта.

# %% [markdown]
# d) ЗАВИСИМОСТЬ ЦЕНЫ ОТ ЧИСЛА КОМНАТ

# %%
rooms_data = data.pivot_table(index = 'rooms', values = 'price_for_square_meter', aggfunc = ['mean', 'count', 'median'])
#Сводная таблица с данными цены объекта в зависимости от количества комнат.
rooms_data.columns = ['mean', 'count', 'median']
display(rooms_data.query('count > 30').sort_values('median', ascending = False))
rooms_data.query('count > 30').plot(y = 'median') #не включаем единичные случаи, чтобы картина была правдоподобнее
display(rooms_data)
print('Коэффициент корреляции Пирсона:', data['rooms'].corr(data['price_for_square_meter']))
data.plot(x = 'rooms', y = 'price_for_square_meter', kind='scatter', alpha=0.03, xlim=(-1,10), ylim=(0,900000))
# Out:
#                 mean  count         median
# rooms
# 7      192002.960095     32  109996.067198
# 0      107364.291836    171  105042.016807
# 6      155406.614387     62  100085.705093
# 1       99665.227654   6734   99714.285714
# 5      125820.061340    193   93687.500000
# 2       93355.938911   6345   91666.666667
# 4      103981.985239    782   88826.181543
# 3       94345.587510   4276   87500.000000
#                 mean  count         median
# rooms
# 0      107364.291836    171  105042.016807
# 1       99665.227654   6734   99714.285714
# 2       93355.938911   6345   91666.666667
# 3       94345.587510   4276   87500.000000
# 4      103981.985239    782   88826.181543
# 5      125820.061340    193   93687.500000
# 6      155406.614387     62  100085.705093
# 7      192002.960095     32  109996.067198
# 8      196426.156260      7  116056.485356
# 9       86951.528132      3   72340.425532
# 10     104828.543618      2  104828.543618
# ...

# %% [markdown]
# На данном графике видно, что цена за квадратный метр уменьшается, приближаясь к отметке в "3 комнаты", затем цена за квадратный метр опять возрастает. Цена за квадратный метр в 3-ех и 4-ех комнатных квартирах примерно одинаковая.
#
# Коэффицент корреляции Пирсона, равный 0,04 говорит о том, что нет прямой зависимости между показателем цены за квадратный метр и числом комнат в квартире.
#
# Наибольшей плотностью охарактеризованы объявления 2- и 1-комнатных объектов, далее плотность идёт на спад.

# %% [markdown]
# d) ЗАВИСИМОСТЬ ЦЕНЫ ОБЪЕКТА ОТ ЭТАЖА

# %%
data_floor_id = data.pivot_table(index = 'floor_id', values = 'price_for_square_meter', aggfunc = ['mean', 'count', 'median'])
data_floor_id.columns = ['mean', 'count', 'median']
data_floor_id.sort_values('median', ascending = False).plot(y = 'median', kind='bar', ylim=(0,100000))
data_floor = data.pivot_table(index = 'floor', values = 'price_for_square_meter', aggfunc = ['mean', 'count', 'median'])
data_floor.columns = ['mean', 'count', 'median']
data_floor.sort_values('median', ascending = False).plot(y = 'median', kind='bar', ylim=(0,120000))
display(data_floor_id)
print('Коэффициент корреляции Пирсона:', data['floor'].corr(data['price_for_square_meter']))
data_floor.sort_values(by='median').head() #поиск аномальных значений
# Out:
#                     mean  count        median
# floor_id
# другой     101052.926532  13864  96916.594641
# первый      80252.418694   2222  80436.769732
# последний   91061.766017   2526  87211.188077
# Коэффициент корреляции Пирсона: 0.14301440435741072
#                mean  count        median
# floor
# 1      80252.418694   2222  80436.769732
# 27     92476.743449     10  87916.214207
# 2      92050.949961   2599  89242.053790
# 5      94613.396605   2025  90460.526316
# 26     93872.574322     20  90742.382397

# %% [markdown]
# Первый этаж является самым дешевым. Последние этажи дороже первых, но обычно не намного. Дорогими являются промежуточные этажи. На столбчатой диаграмме видно, что наиболее дорогими этажами являются те, что расположены ближе к последнему в домах высотных зданий.

# %% [markdown]
# e) ЗАВИСИМОСТЬ ЦЕНЫ ОБЪЕКТА ОТ ДНЯ НЕДЕЛИ:

# %%
data['weekday_exposition'] = data['first_day_exposition'].dt.weekday

# %%
data_weekday = data.pivot_table(index = 'weekday_exposition', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
data_weekday.columns = ['mean', 'count', 'median']
display(data_weekday.sort_values('median', ascending = False))
print('Коэффициент корреляции Пирсона:', data['weekday_exposition'].corr(data['last_price']))
data_weekday.sort_values('median', ascending = False).plot(y = 'median', kind='bar', ylim=(0,6000000))
# Out:
#                             mean  count   median
# weekday_exposition
# 0                   6.005691e+06   2779  4500000
# 1                   5.892794e+06   3268  4500000
# 2                   6.138012e+06   3072  4500000
# 3                   5.963525e+06   3385  4500000
# 5                   6.854942e+06   1525  4500000
# 4                   5.816181e+06   3240  4400000
# 6                   5.785338e+06   1343  4390000
# Коэффициент корреляции Пирсона: 0.004379275366219282
# <AxesSubplot:xlabel='weekday_exposition'>

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# Считать корреляцию для категориальных данных не корректно, так как корреляция применима только к линейным зависимостям, а зависимость от категории этажа, дня недели, месяца или года не линейна, чаще всего там есть сезонность. Тут лучше просто построить столбчатую диаграмму по медианам.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента</font></h5>
#
# Построил графики типа barplot, добавил выводы для этажа, дня недели, дня месяца, месяца и года.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍
#
# </div>

# %% [markdown]
# Четкой взаимосвязи между днем недели и ценой объекта нет, об этом же говорит коэффициент корреляции Пирсона 0.004. Можно разве что утверждать, что объявления с наибольшей ценой публикуются чаще во вторник, а с наименьшей - в воскресенье.

# %% [markdown]
# f) ЗАВИСИМОСТЬ ЦЕНЫ ОБЪЕКТА ОТ ДНЯ МЕСЯЦА:

# %%
data_day = data.pivot_table(index = 'day_of_publication', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
data_day.columns = ['mean', 'count', 'median']
display(data_day.sort_values('median', ascending = False))
print('Коэффициент корреляции Пирсона:', data['day_of_publication'].corr(data['last_price']))
data_day.sort_values('median', ascending = False).plot(y = 'median', kind='bar', ylim=(0,6000000))
# Out:
#                             mean  count   median
# day_of_publication
# 29                  6.078654e+06    519  4750000
# 4                   7.027359e+06    526  4700000
# 27                  6.077236e+06    619  4700000
# 12                  6.315820e+06    672  4690000
# 10                  6.833699e+06    915  4600000
# 13                  6.194429e+06    693  4580000
# 23                  5.931023e+06    535  4550000
# 16                  6.178666e+06    602  4500000
# 5                   5.349766e+06    494  4500000
# 20                  6.336189e+06    695  4500000
# 18                  6.381459e+06    591  4500000
# 11                  5.612986e+06    658  4500000
# 31                  6.537308e+06    255  4490000
# 3                   5.485122e+06    510  4475000
# 24                  6.367744e+06    506  4470000
# 21                  5.753614e+06    630  4450000
# 15                  5.659269e+06    657  4450000
# 2                   5.627701e+06    531  4425000
# ...

# %% [markdown]
# Зависимости между ценой и днем публикации нет, коэффициент корреляции Пирсона равен 0.006. Данные сильно разнятся, четких закономерностей не обнаружено. Можно разве что утверждать, что объявления с наибольшей ценой публикуются чаще в 4-ый день месяца, а с наименьшей - в 6-ой.

# %% [markdown]
# g) ЗАВИСИМОСТЬ ЦЕНЫ ОБЪЕКТА ОТ МЕСЯЦА:

# %%
data_month = data.pivot_table(index = 'month_of_publication_id', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
data_month.columns = ['mean', 'count', 'median']
display(data_month.sort_values('median', ascending = False))
print('Коэффициент корреляции Пирсона:', data['month_of_publication_id'].corr(data['last_price']))
data_month.sort_values('median', ascending = False).plot(y = 'median', kind='bar', ylim=(0,6000000))
# Out:
#                                  mean  count     median
# month_of_publication_id
# 9                        6.560650e+06   1706  4599500.0
# 11                       6.061252e+06   1996  4550000.0
# 2                        6.004400e+06   2117  4500000.0
# 4                        6.497057e+06   1358  4500000.0
# 7                        6.090708e+06   1445  4500000.0
# 8                        5.762709e+06   1505  4500000.0
# 1                        5.795758e+06   1168  4499499.5
# 5                        6.129007e+06    995  4450000.0
# 10                       5.637622e+06   1789  4450000.0
# 12                       6.209930e+06   1283  4449000.0
# 3                        5.682503e+06   1749  4400000.0
# 6                        5.928944e+06   1501  4300000.0
# Коэффициент корреляции Пирсона: 0.004437875112258898
# <AxesSubplot:xlabel='month_of_publication_id'>

# %% [markdown]
# Зависимость между месяцами и ценой объекта также не выявлена, коэффициент корреляции Пирсона равен 0.004. Можно разве что утверждать, что объявления с наибольшей ценой публикуются чаще в апреле, а с наименьшей - в июне.

# %% [markdown]
# h) ЗАВИСИМОСТЬ ЦЕНЫ ОБЪЕКТА ОТ ГОДА:

# %%
data_year = data.pivot_table(index = 'year_of_publication', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
data_year.columns = ['mean', 'count', 'median']
display(data_year.sort_values('median', ascending = False))
print('Коэффициент корреляции Пирсона:', data['year_of_publication'].corr(data['last_price']))
data_year.sort_values('median', ascending = False).plot(y = 'median', kind='bar', ylim=(0,8000000))
# Out:
#                              mean  count   median
# year_of_publication
# 2019                 5.868534e+06   1083  4789500
# 2015                 7.108714e+06    439  4700000
# 2018                 5.590009e+06   7513  4490000
# 2016                 6.480913e+06   2048  4465000
# 2017                 6.283822e+06   7529  4450000
# Коэффициент корреляции Пирсона: -0.03309235265498308
# <AxesSubplot:xlabel='year_of_publication'>

# %% [markdown]
# На данном графике видно, что в 2014 году выкладывались объявления с наиболее дорогими объектами. Наиболее дешевые объекты были выставлены на продажу в 2016, 2017 и 2018 годах. Корреляция не обнаружена между показателями "цена" и "год", коэффициент Пирсона = -0.033. Нет линейной зависимости.

# %% [markdown]
# **Посчитаем среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделим населённые пункты с самой высокой и низкой стоимостью квадратного метра.**

# %%
top_10 = data.pivot_table(index='locality_name', values='price_for_square_meter',
                          aggfunc=['mean', 'count'])
top_10.columns = ['mean_price_for_square_meter', 'count_price_for_square_meter']
top_10 = top_10.sort_values(by='count_price_for_square_meter', ascending=False).head(10)
top_10 #Выводим сводную таблицу средней цены квадратного метра для топ 10 населённых пунктов по количеству объявлений.
# Out:
#                  mean_price_for_square_meter  count_price_for_square_meter
# locality_name
# Санкт-Петербург                111409.958431                         12330
# Мурино                          85929.958104                           513
# Кудрово                         94487.316848                           402
# Шушары                          77792.490162                           384
# Всеволожск                      68542.224485                           307
# Колпино                         74779.509490                           293
# Парголово                       89186.224782                           287
# Пушкин                         101800.547460                           277
# Гатчина                         68065.179716                           244
# Выборг                          56946.355622                           192

# %%
top_10.sort_values(by='mean_price_for_square_meter', ascending=False).plot(y='mean_price_for_square_meter', kind='bar')
# Out:
# <AxesSubplot:xlabel='locality_name'>

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h5>
#
# ✅ Спасибо за интересные наблюдения 😃
#
# Желательно отсортировать данные перед построением, чтобы было проще сравнивать.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента</font></h5>
#
# Добавил сортировку на графике по убыванию цены.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍
#
# </div>

# %% [markdown]
# Среди топ 10 населённых пунктов по количеству объявлений наиболее дорогим исходя из средней цены за квадратный метр является Санкт-Петербург, а наиболее дешевым - Выборг. Средняя цена за квадратный метр в Санкт-Петербурге составляет 111410. Средняя цена за квадратный метр в Выборге составляет 56946.

# %% [markdown]
# Найдем населённые пункты с самой большой и с самой маленькой стоимостью объекта недвижимости:

# %%
data_price_min_max = data.pivot_table(index = 'locality_name', values = 'price_for_square_meter', aggfunc = ['mean','median'])
data_price_min_max.columns = ['mean','median']
display('самые дешевые объекты находятся в',
        data_price_min_max[data_price_min_max['mean'] == data_price_min_max['mean'].min()])
display('самые дорогие объекты находятся в',
        data_price_min_max[data_price_min_max['mean'] == data_price_min_max['mean'].max()])
# Out:
# 'самые дешевые объекты находятся в'
#                        mean   median
# locality_name
# Старополье     11206.221198  11000.0
# 'самые дорогие объекты находятся в'
#                        mean        median
# locality_name
# Лисий Нос      113728.34873  113728.34873

# %%
data = data.assign(city_centers_nearest_km_int = data['city_centers_nearest_km'].fillna(500))
# заполним пропущенные значения в данном столбце, что бы можно было исключить их из графика и построить его.
data_spb_price_for_km = data.query('locality_name == "Санкт-Петербург" and city_centers_nearest_km_int !=500').pivot_table(
    index = 'city_centers_nearest_km_int', values = 'last_price', aggfunc = 'mean')
data_spb_price_for_km.plot()
data_spb_price_for_km.sort_values(by='last_price', ascending=False)
# Out:
#                                last_price
# city_centers_nearest_km_int
# 0.6                          4.313333e+07
# 0.4                          4.263750e+07
# 7.9                          3.159149e+07
# 4.0                          2.984297e+07
# 1.7                          2.779286e+07
# ...                                   ...
# 23.2                         2.974286e+06
# 26.3                         2.600000e+06
# 29.5                         2.450000e+06
# 24.4                         2.400000e+06
# 27.4                         2.250000e+06
#
# [254 rows x 1 columns]

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Супер, корректно выделены квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислена средняя цена каждого километра.
#
# </div>

# %% [markdown]
# Чем ближе к центру находится объект, тем выше цена за квадратный метр. Цена сильно падает после 7 км. Следовательно, можно обозначить радиус в 7 км как центр города. Далее цена плавно падает вплоть до 26 км, что свидетельствует о том, что есть достаточно дорогие районы на окраине города.

# %% [markdown]
# **Исследование завершено, можно писать общий вывод**

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# Исследование было посвящено объявлениям о продажах квартир.
#
# - Была получена первоначальная информация по датасету.
#
# - Обнаружены пропуски в датасете, кол-во некоторых доходит до 88.29%. Кол-во столбцов с пропусками 14 (всего в датасете 22 столбца).
# - Явных дубликаты в датасете не было обнаружено.
# - Замечены аномалии, к примеру, минимальное значение потолка 1 метр, а максимальное 100 метров.
#
# - Найдены пропуски, неявные дубликаты и аномалии в датасете.
# - Была проведена работа по заполнению пропусков, удаление ненужных строк из датасета.
# - Аномалии и дубликаты обработаны.
#
# - Заменены неявные дубликаты (раньше названия населенных пунктов повторялись из-за разной записи).
# - Столбец с датой приведен к округленному до дней и правильному форматам.
# - Пропуски в столбце с высотой потолков заменены медианным значением.
# - Пропуски в kitchen area исправлены на значение равное 17.2% от общей площади квартиры, что является медианным значением. - - - - Пропуски в living area исправлены на значение равное 56.8% от общей площади квартиры, что является медианным значением.
# - Удалены квартиры, которые продаются больше 500 дней, кол-во квартир от всего датасета составляет 7.35%.
# - Было выявлено, что пропуски в данных с количеством парков и прудов в радиусе 3000 метров означали отсутсвие таковых в данном радиусе. Пропуски были заменены на значение 3001.
#
# Были изменены типы данных некоторых столбцов, где это необходимо.
#
# В датафрейм добавлены новые показатели:
#
# отношение кухни и жилой площади к общей площади помещения, цена за кв метр, день, месяц и год публикации объявлений, категория этажа.
#
# Время продаж в основном приходится на 2017 и 2018 год (немного больше 8000 объявлений).
#
# Среднее значение длительности размещения квартиры на площадке Яндекса равняется 180 дням, а медиана равна 95 дням.
#
# Выявлены выбивающиеся значения. Аномалии находятся на 45, 60, 7, 30, 90 днях. Данные аномалии связаны с тем, что сроки публикации на яндексе соответсвуют этим дням.
#
# - Продажа комнаты - 45 дней
# - Продажа дома, участка или гаража - 90 дней
# - Аренда комнаты - 7 днейАренда комнаты, участка или гаража - 30 дней
# - Аренда и продажа коммерческого объекта - 60 дней
# - Продажа квартиры: до 4,5 млн — 45 дней, от 4,5 до 10 млн — 60 дней, от 10 млн — 90 дней
# - Аренда квартиры: до 20 тыс/м — 7 дней, от 20 до 40 тыс/м — 14 дней, от 40 тыс/м — 21 день
# - Аренда посуточная: Квартира, Комната, Дом / участок, Гараж - 60 дней.
#
# Построены распределения и статистические данные по основным параметрам объекта и сделаны общие выводы:
#
# - **Общая площадь:** Значения лежат в диапозоне от 12 до 900 м2. Среднее значение 60 м2, медианное значение 52 м2. Данные распределены нормально, пикующие значения наблюдаются в области 35-40 м2 и 55-60 м2 - средние площади одно- и двухкомнатных квартир.
#
# - **Жилая площадь:** Значения лежат в диапозоне от 2 до 410 м2. Среднее значение 34 м2, медианное значение 30 м2. Данные распределены нормально, пикующие значения наблюдаются в области 15-20 м2 и 28-30 м2 - средние жилые площади одно- и двухкомнатных квартир. Есть редкие выбросы в районе 40-43 м2, не влияющие на данные. Нижняя граница составляет 2 м2 при нижней границе общей площади 12 м2, что может говорить о некоторой некорректности данных в области нижних границ распределения, однако таких значений мало по отношению к общему числу данных. Возможно в данных содержится информация о нежилых помещениях типа гаража или кладовки.
#
# - **Кухонная площадь:** Значения лежат в диапозоне от 1.3 до 112 м2. Среднее значение 10.4 м2, медианное значение 9 м2. Данные распределены нормально, пикующие значения наблюдаются в областях 5, 7 и 11 м2. Нижняя граница составляет 1 м2 при нижней границе общей площади 12 м2, что может говорить о некоторой некорректности данных в области нижних границ распределения, однако таких значений мало по отношению к общему числу данных. Возможно в данных содержится информация о нежилых помещениях типа гаража или кладовки.
#
# - **Цена объекта в объявлении:** Значения лежат в диапозоне от 12190 до 763000000. Среднее значение 6490621, медианное значение 4610000. Данные распределены нормально, явных пикующих значений не обнаружено.
#
# - **Количество комнат:** Значения лежат в диапозоне от 0 до 19. Среднее значение 2, медианное значение 2. Данные распределены нормально. Большинство объектов имеют одну или две комнаты. Есть объекты, которые не содержат комнат, что еще раз говорит о содержании нежилых помещений в данных.
#
# - **Этаж объекта:** Значения лежат в диапозоне от 1 до 33. Среднее значение 6, медианное значение 4. Данные можно описать экспоненциально с пороговым значением в районе 1. Большинство объектов находятся в диапозоне от 1 до 5 этажа, далее распределение убывает.
#
# - **Число этажей в доме объекта:** Значения лежат в диапозоне от 1 до 60. Среднее значение 11, медианное значение 9. Основные пики наблюдаются в значениях 5 и 9 этажей. Менее пикующие значения: 13, 17 и 26 этажей.
#
# - **Расстояние от объекта до центра города:** Значения лежат в диапозоне от 0.2 до 66 км. Среднее значение 14.2 км, медианное значение 13.1 км. Имеется явный провал в данных в диапозоне 6-10 км, что создаёт два пика по обеим сторонам от провала.
#
# - **Расстояние от объекта до ближайшего аэропорта:** Значения лежат в диапозоне от 0 до 84.9 км. Среднее значение 28.8 км, медианное значение 26.8 км. Данные распределены по всему диапозону с множеством пиков, с возрастанием значением распределение убывает. Есть аномальные значения в районе 0, которое можно отбросить.
#
# - **День публикации объявления:** Значения лежат в ожидаемом диапозоне от 1 до 31 числа месяца. Среднее значение 15, медианное значение 15. Существуют выбросы в значениях 1 числа месяца и 10 числа месяца - наиболее популярные дни публикаций объявления.
#
# - **Месяц публикации объявления:** Значения лежат в ожидаемом диапозоне от 1 до 12. Среднее значение 6, медианное значение 6. Существуют выбросы в значении 12 - наибольшее число объявлений публикуется в конце года. Наименьшие значения 1 и 5 - в январе и мае.
#
# - **Год публикации объявления:** Значения лежат в ожидаемом диапозоне от 2014 до 2019 года. Среднее значение 2017, медианное значение 2017. Платфома Яндекс.Недвижимость набирала популярность с каждым годом - число публикаций год к году росло. Данные для 2019 года неполные - до мая 2019 года, поэтому наблюдается провал. Данные для 2014 года также неполные и начинаются с ноября.
#
# - **Высота потолков**: Значения лежат в диапозоне от 2 до 4 м, так как остальные аномальные значения были ранее отброшены. Среднее значение 2.69 м, медианное значение 2.65 м. Наблюдаются явные пики в значениях 2.5 и 2.65 (медиана) метров.
#
# - **Расстояние от объекта до ближайшего парка:** Значения исследовались в диапозоне от 0 до 3000 метров. Распределение лежит в диапозоне от 1 до 2984 м. Среднее значение 489 м, медианное значение 454 м. Распределение нормальное с редкими выбросами после 1000 м.
#
# - **Расстояние от объекта до ближайшего пруда:** Значения исследовались в диапозоне от 0 до 3000 метров. Распределение лежит в диапозоне от 13 до 1344 м. Среднее значение 518.4 м, медианное значение 503 м. Распределение нормальное.
#
# Сделаны графики соотношений цены к другим показателям квартир
#
# - *Корреляция ЦЕНА-ОБЩАЯ ПЛОЩАДЬ* = 0.621. Чем больше общая площадь помещения, тем выше цена. Основная плотность числа объявлений находится в дипазоне 0-120 м2 по общей площади и 0-18000000 по цене объекта.
#
# - *Корреляция ЦЕНА-ЖИЛАЯ ПЛОЩАДЬ* = 0.549. Чем больше жилая площадь помещения, тем выше цена. Основная плотность числа объявлений находится в дипазоне 0-70 м2 по жилой площади и 0-16000000 по цене объекта.
#
# - *Корреляция ЦЕНА-КУХОННАЯ ПЛОЩАДЬ* = 0.477. Чем больше кухонная площадь помещения, тем выше цена. Основная плотность числа объявлений находится в дипазоне 0-21 м2 по кухонной площади и 0-16000000 по цене объекта.
#
# - *Корреляция ЦЕНА – ЧИСЛО КОМНАТ* = 0.04. Цена за квадратный метр уменьшается, приближаясь к отметке в "3 комнаты", затем цена за квадратный метр опять возрастает. Цена за квадратный метр в 3-ех и 4-ех комнатных квартирах примерно одинаковая. Наибольшей плотностью охарактеризованы объявления 2- и 1-комнатных объектов, далее плотность идёт на спад.
#
# - *Корреляция ЦЕНА – ЭТАЖ* = 0.143. Первый этаж является самым дешевым. Последние этажи дороже первых, но обычно не намного. Дорогими являются промежуточные этажи. Наиболее дорогими этажами являются те, что расположены ближе к последнему в домах высотных зданий.
#
# - *Корреляция ЦЕНА – ДЕНЬ НЕДЕЛИ* = 0.004. Четкой взаимосвязи между днем недели и ценой объекта нет. Можно разве что утверждать, что объявления с наибольшей ценой публикуются чаще во вторник, а с наименьшей - в воскресенье.
#
# - *Корреляция ЦЕНА — ДЕНЬ МЕСЯЦА* = 0.006. Зависимости между ценой и днем публикации нет, данные сильно разнятся, четких закономерностей не обнаружено. Можно разве что утверждать, что объявления с наибольшей ценой публикуются чаще в 4-ый день месяца, а с наименьшей - в 6-ой.
#
# - *Корреляция ЦЕНА — МЕСЯЦ* = 0.004. Зависимость между месяцами и ценой объекта также не выявлена, но можно утверждать, что в июне квартиры выставляются по меньшей цене, чем в остальные месяцы. Можно разве что утверждать, что объявления с наибольшей ценой публикуются чаще в апреле, а с наименьшей - в июне.
#
# - *Корреляция ЦЕНА — ГОД* = -0.033. в 2014 году выкладывались объявления с наиболее дорогими объектами. Наиболее дешевые объекты были выставлены на продажу в 2016, 2017 и 2018 годах. Корреляция не обнаружена между показателями "цена" и "год", коэффициент Пирсона = -0.033. Нет линейной зависимости.
#
# Выявлен топ 10 населенных пунктов по кол-ву объявлений:
#
# ![image.png](attachment:image.png)
#
# самые дешевые объекты находятся в Старополье: 11206 (среднее значение цены за кв. м.)
# самые дорогие объекты находятся в Лисий Нос	113728 (среднее значение цены за кв. м.)
#
# Была расчитана средняя цена каждого километра удалённости от центра города Санкт-Петербурга. Из результатов распределения можно сделать выводы:
#
# Чем ближе к центру находится объект, тем выше цена за квадратный метр. Цена сильно падает после 7 км. Следовательно, можно обозначить радиус в 7 км как центр города. Далее цена плавно падает вплоть до 26 км, что свидетельствует о том, что есть достаточно дорогие районы на окраине города.

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h5>
#
# Спасибо, очень хороший и подробный общий вывод, которые содержит все промежуточные результаты.
#
# Скорректируй их, пожалуйста, после того как исправишь недочеты.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента</font></h5>
#
# Выводы были скорректированы исходя из исправленных недочётов.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍
#
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Хорошо, что ты ведешь чек-лист, он помогает ничего не забыть!
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента</font></h5>
#
# Валентин, большое спасибо за подсказки по улучшению проекта, за ревью в целом!
#
# </div>
